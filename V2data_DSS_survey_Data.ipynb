# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import time
import datetime
import warnings

# %%
#show all row length when printing
pd.set_option('display.max_colwidth', -1)
# Out:
# /var/folders/mg/667_zj95427b86bx_17bsgl40000gn/T/ipykernel_18026/682558969.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
#show all columns when printing
pd.set_option('display.max_columns', None)

# %%
survey_data = pd.read_csv('/Users/giovannibalestrieri/Desktop/Decision Support Systems/Group Assignement/participant data v2 Nov 24/survey data/msi_response.csv')

# %%
survey_data
# Out:
#                                                                user_id  \
# 0     aa9f0c3c08e5550ae1942640f4e1bfc21ec4af4724fd8a43d812458eb7a4e2e7
# 1     aa9f0c3c08e5550ae1942640f4e1bfc21ec4af4724fd8a43d812458eb7a4e2e7
# 2     aa9f0c3c08e5550ae1942640f4e1bfc21ec4af4724fd8a43d812458eb7a4e2e7
# 3     aa9f0c3c08e5550ae1942640f4e1bfc21ec4af4724fd8a43d812458eb7a4e2e7
# 4     aa9f0c3c08e5550ae1942640f4e1bfc21ec4af4724fd8a43d812458eb7a4e2e7
# ...                                                                ...
# 1579  97472f2a327d3ed90f57376affc67f47607245401d27eaba675bdbb440a2d6e3
# 1580  97472f2a327d3ed90f57376affc67f47607245401d27eaba675bdbb440a2d6e3
# 1581  97472f2a327d3ed90f57376affc67f47607245401d27eaba675bdbb440a2d6e3
# 1582  97472f2a327d3ed90f57376affc67f47607245401d27eaba675bdbb440a2d6e3
# 1583  97472f2a327d3ed90f57376affc67f47607245401d27eaba675bdbb440a2d6e3
#
#                    item_id                    value  start_ts       stop_ts
# ...

# %%
#survey_data[survey_data['user_id'] == '193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446']

# %%
group = survey_data[survey_data['item_id']=='group']
group4 = ['Group number 4 ', 'Group 4', 'GROUP 4','groep 4','4','What group?']
group = group[group['value'].isin(group4)]
users = group['user_id'].unique()

# %%
users
# Out:
# array(['193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446',
#        '9437dc89b5bb246db5fcf9f45311e7b07a13759e87609efe8b79759e69a3d463',
#        '79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed',
#        '551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5',
#        '58f837a105c6522d77e92b579551994b382885c33109e08252aa30cbc46501d8',
#        '190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49',
#        'a1fca725e356f6a875477765434bf7293ee42d8fb723ea287980609e67280287',
#        '310c2c931b0a40733bceb933951538cff2cbf5efba6c86eb30017d138f8615a2',
#        'd5fe9ff3491247b295c45050b90ac74d897e6a266f739d30529fad9b377d95a7',
#        '33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156',
#        '05304b1f0426de6f6659ee3705d94276f0879f5f82620135d6e3129cd7dd38f6',
#        '2aba0b9f77711c3efa0de1abd12456d955d6dd5fe5cc6516dbbfeeec055430dc',
# ...

# %%
genre_data = pd.read_csv('/Users/giovannibalestrieri/Desktop/Decision Support Systems/Group Assignement/participant data v2 Nov 24/recommendation data/rec_genres.csv')

# %%
#print the gerne data where user is 193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
#genre_data[genre_data['user_id']=='193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446']

# %%
top_tracks = pd.read_csv('/Users/giovannibalestrieri/Desktop/Decision Support Systems/Group Assignement/participant data v2 Nov 24/user spotify data/top_tracks.csv')
top_tracks.sample(10)
# Out:
#                                                                 user_id  \
# 519    1418fcc80d2e4febb58f44fcd93ff755df16b64edfa90076ab6e6707d79453ba
# 436    ed56810fb3ca5f82385492151b3d37f9f2d21eabebef21d794280a86917619ff
# 10340  9a56b76ebcc78e6344d0860dc4ba0586fbb59a390c95d3ca4e6c8e79388c7883
# 12246  03b5f19ae66487498f226418d775eb5844d738d0b22c866abf0c0cd3fb43fdbb
# 12659  65637078cef70e5d97029f181a57218ebaecea63e96184716310e3f0f12057e1
# 12652  65637078cef70e5d97029f181a57218ebaecea63e96184716310e3f0f12057e1
# 9752   755ad5d4ec6b57c2104da88df2e983fe732701704d163a788e2dab3e94c48d5e
# 8492   6c8d3f983a66980e19449d899a47808b804a121e66a3e8decc8bbd056e82901e
# 651    c90398ac27b0f7ed99d1265d9af1ea5080ed6854110c7d765a3f493faf376931
# 6456   b1bd87ca84f7c28cefbfcd0b71246db20045c75b48ad949b71677370c68c72f3
#
#                      track_id time_period     timestamp  position  session_num
# 519    76voC75r72iKgNsmEMkDBX  long        1.667506e+09  47        1
# ...

# %%
top_tracks[top_tracks['user_id']=='193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446'].sample(10)
# Out:
#                                                                 user_id  \
# 11851  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11790  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11848  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11868  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11817  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11791  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11844  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11811  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11783  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11869  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
#
#                      track_id time_period     timestamp  position  session_num
# 11851  4XMdp1Z5d5WrUZBmwIV8RG  medium      1.699909e+09  19        1
# ...

# %%
#get just the rows where time_period = 'short_term'
top_tracks_short = top_tracks[top_tracks['time_period']=='short']
len(top_tracks)
# Out:
# 24139

# %%
#get just the data where user is in the users list
top_tracks_short = top_tracks_short[top_tracks_short['user_id'].isin(users)]
len(top_tracks_short)
# Out:
# 970

# %%
#count the number of rows for each user
top_tracks_short.groupby('user_id').count()
# Out:
#                                                                   track_id  \
# user_id
# 05304b1f0426de6f6659ee3705d94276f0879f5f82620135d6e3129cd7dd38f6  50
# 190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49  50
# 193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446  50
# 2aba0b9f77711c3efa0de1abd12456d955d6dd5fe5cc6516dbbfeeec055430dc  50
# 310c2c931b0a40733bceb933951538cff2cbf5efba6c86eb30017d138f8615a2  50
# 33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156  50
# 511b89b7678ce0a6e47fb855449464db2e11ee734c301e02b6ce64d1028f68f3  55
# 551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5  50
# 58f837a105c6522d77e92b579551994b382885c33109e08252aa30cbc46501d8  50
# 612a1db40349f4a4af4bb80973dc6465438019891bd96d3ff5407c47fb621e9b  50
# 79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed  50
# 90bfc065f3b6aa5d8a99acdb968507dafc3827128e4244bba1c192f5d2ef0b73  50
# ...

# %%
#print where user is 193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
top_tracks_short[top_tracks_short['user_id']=='193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446']
# Out:
#                                                                 user_id  \
# 11728  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11729  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11730  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11731  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11732  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11733  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11734  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11735  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11736  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11737  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11738  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 11739  193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# ...

# %%
tracks = pd.read_csv('/Users/giovannibalestrieri/Desktop/Decision Support Systems/Group Assignement/participant data v2 Nov 24/track and artist data/track.csv')
tracks.sample(10)
# Out:
#                            id  \
# 8027   6sS4XjeyUg51rZtrXOBddD
# 49455  7htmRcPbmrY9oenatxz9UL
# 37037  0CmXXEwul09Kf8X68lPA5l
# 13687  5ZtKJy1I3RfBfgEPiTWaDn
# 42290  1ss4CfqZagd4a7A0CBkqZY
# 12520  2a5Rgz0tcXZU5uH2xmWzBg
# 50337  61Ivix5DTnDPVjp1dgLyov
# 17651  6I9eLxul8fM899LS2T0w5X
# 22934  5qTvkDrSfvwDv6RBjjcfQr
# 22114  7sj71Y12St8KlvMpBt4K27
#
#                                                            trackname  \
# 8027   Symphony No. 94 in G Major, Hob. I:94 "Surprise": II. Andante
# 49455  Latest Trends (feat. Aitch) - Remix
# 37037  Missing You
# 13687  Goldrush
# 42290  Vámonos - LNY TNZ Remix
# 12520  La ritournelle (Gilligan Moss Mix)
# 50337  Disco Yes
# 17651  3,000 Miles
# 22934  Get Busy
# 22114  Hagamos Un Trato
#
#        popularity  \
# 8027   19
# 49455  58
# 37037  56
# 13687  34
# 42290  40
# 12520  51
# 50337  1
# 17651  11
# 22934  76
# 22114  56
#
# ...

# %%
#rename the column id to track_id
tracks.rename(columns={'id':'track_id'}, inplace=True)

# %%
#left join top_tracks and tracks on track_id
user_tracks_top_tracks = pd.merge(top_tracks_short, tracks, on='track_id', how='left')

# %%
user_tracks_top_tracks.sample(10)
# Out:
#                                                               user_id  \
# 226  79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed
# 467  d5fe9ff3491247b295c45050b90ac74d897e6a266f739d30529fad9b377d95a7
# 685  2aba0b9f77711c3efa0de1abd12456d955d6dd5fe5cc6516dbbfeeec055430dc
# 958  90bfc065f3b6aa5d8a99acdb968507dafc3827128e4244bba1c192f5d2ef0b73
# 341  58f837a105c6522d77e92b579551994b382885c33109e08252aa30cbc46501d8
# 565  33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156
# 263  551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5
# 168  e125a1762ff5d8136d0215181b950c586493ae05d82872f1ba546545064994e4
# 439  a1fca725e356f6a875477765434bf7293ee42d8fb723ea287980609e67280287
# 58   9437dc89b5bb246db5fcf9f45311e7b07a13759e87609efe8b79759e69a3d463
#
#                    track_id time_period     timestamp  position  session_num  \
# 226  5zqGqFaBnzX5JeUHqNWR3K  short       1.700473e+09  26        1
# ...

# %%
user_tracks_top_tracks.groupby('user_id').count()
# Out:
#                                                                   track_id  \
# user_id
# 05304b1f0426de6f6659ee3705d94276f0879f5f82620135d6e3129cd7dd38f6  50
# 190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49  50
# 193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446  50
# 2aba0b9f77711c3efa0de1abd12456d955d6dd5fe5cc6516dbbfeeec055430dc  50
# 310c2c931b0a40733bceb933951538cff2cbf5efba6c86eb30017d138f8615a2  50
# 33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156  50
# 511b89b7678ce0a6e47fb855449464db2e11ee734c301e02b6ce64d1028f68f3  55
# 551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5  50
# 58f837a105c6522d77e92b579551994b382885c33109e08252aa30cbc46501d8  50
# 612a1db40349f4a4af4bb80973dc6465438019891bd96d3ff5407c47fb621e9b  50
# 79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed  50
# 90bfc065f3b6aa5d8a99acdb968507dafc3827128e4244bba1c192f5d2ef0b73  50
# ...

# %%
#save the data to a csv file
user_tracks_top_tracks.to_csv('/Users/giovannibalestrieri/Desktop/Decision Support Systems/Group Assignement/participant data v2 Nov 24/user spotify data/users_and_tracks.csv', index=False)

# %%
#save al row of user_id = '193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446' in a dataframe
user0_tracks_top_tracks = user_tracks_top_tracks[user_tracks_top_tracks['user_id']=='190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49']

# %%
user0_tracks_top_tracks
# Out:
#                                                               user_id  \
# 350  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 351  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 352  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 353  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 354  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 355  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 356  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 357  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 358  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 359  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 360  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 361  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# ...

# %%
#plot the distibution of acousticness	danceability	duration_ms	energy	instrumentalness	key	liveness	loudness	speechiness	tempo	time_signature	valence for user0 with a line following the distribution
fig, ax = plt.subplots(4, 3, figsize=(20, 20))
sns.distplot(user0_tracks_top_tracks['acousticness'], ax=ax[0,0])
sns.distplot(user0_tracks_top_tracks['danceability'], ax=ax[0,1])
sns.distplot(user0_tracks_top_tracks['duration_ms'], ax=ax[0,2])
sns.distplot(user0_tracks_top_tracks['energy'], ax=ax[1,0])
sns.distplot(user0_tracks_top_tracks['instrumentalness'], ax=ax[1,1])
sns.distplot(user0_tracks_top_tracks['key'], ax=ax[1,2])
sns.distplot(user0_tracks_top_tracks['liveness'], ax=ax[2,0])
sns.distplot(user0_tracks_top_tracks['loudness'], ax=ax[2,1])
sns.distplot(user0_tracks_top_tracks['speechiness'], ax=ax[2,2])
sns.distplot(user0_tracks_top_tracks['tempo'], ax=ax[3,0])
sns.distplot(user0_tracks_top_tracks['time_signature'], ax=ax[3,1])
sns.distplot(user0_tracks_top_tracks['valence'], ax=ax[3,2])
plt.show()
# Out:
# /var/folders/mg/667_zj95427b86bx_17bsgl40000gn/T/ipykernel_18026/3042027551.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(user0_tracks_top_tracks['acousticness'], ax=ax[0,0])
# /var/folders/mg/667_zj95427b86bx_17bsgl40000gn/T/ipykernel_18026/3042027551.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
top_artists = pd.read_csv('/Users/giovannibalestrieri/Desktop/Decision Support Systems/Group Assignement/participant data v2 Nov 24/user spotify data/top_artists.csv')
top_artists.sample(10)
# Out:
#                                                                 user_id  \
# 6940   fc8ef674e488a7487a5aff9a162b98f27a52a6636652fd516b48cf23790bdf82
# 19690  97472f2a327d3ed90f57376affc67f47607245401d27eaba675bdbb440a2d6e3
# 5593   65ee203a47c9150d043f3f2775c071a0d7e1d24abb7992ddd28e079e08c1a79e
# 11859  e85a5f176e3cd5d3d97902833d63872aa028bf55f507299aaa98ca4e6b1cf711
# 9074   704030ff594414c053a16117afd77ad71da1581fa0e0fa7e0735fc3ed45b7bcd
# 1992   68eafc018c4d94711f051a4f6279a5b35943a0b554c50f95e7c28d29fe63a52b
# 13068  e4090d6b3587b617ceaf54bbbbebed5b2f047a6a218ddd22aca92203cac690ca
# 19513  1e17eb695d38923f8284035b2d194deeef1f9c59234882c33dd6ed94d750aa5a
# 18133  a42310f730b452bf268844947aac6ec34cd16d79c79945eaf69fcd198e6ab0e5
# 7391   8637baa65e53b964df6936171b613cfa48d055b0372ef363192faf0650c8c0fa
#
#                     artist_id time_period     timestamp  position  session_num
# 6940   5RJFJWYgtgWktosLrUDzff  medium      1.668707e+09  47        1
# ...

# %%
top_artists_short = top_artists[top_artists['time_period']=='short']
top_artists_short.sample(10)
# Out:
#                                                                 user_id  \
# 13832  551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5
# 7809   5fb1db52d3b6b053aa2964d19fa99b1ec5b31ee8108d87055f2ce7898d62b9cc
# 13869  dba9e80339ce755929b236448f3bcc0dedeee86de644e935ff1d07bb3e52b837
# 3762   7e74c3e072351881bde701e6b5ded657082b4f80f5d1bf3452d74d2de8e34df6
# 2634   3817d9a405254d9e075f6faf86ff7e92dd972a8448205f99fd2ec21482328fde
# 6255   00c8aae385389f159752b62e58288f9dc0bb7549dabc19d2c159d3b453ca9a6c
# 13642  79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed
# 13050  e4090d6b3587b617ceaf54bbbbebed5b2f047a6a218ddd22aca92203cac690ca
# 447    e974cba2faff9330e385a7e3d952bc8c64518a73cfd18e79dc149051e879daa7
# 10668  5834b24b0f09ef625234912b90ce2736915962ceb5ef7d8db56c299a71b060e6
#
#                     artist_id time_period     timestamp  position  session_num
# 13832  4lhUHpVOXmkEBGGHV71QCh  short       1.700473e+09  36        1
# ...

# %%
#get only the users in the users list
top_artists_short = top_artists_short[top_artists_short['user_id'].isin(users)]
top_artists_short.sample(10)
# Out:
#                                                                 user_id  \
# 15264  a1fca725e356f6a875477765434bf7293ee42d8fb723ea287980609e67280287
# 13456  e125a1762ff5d8136d0215181b950c586493ae05d82872f1ba546545064994e4
# 14554  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 15642  33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156
# 13630  79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed
# 15920  2aba0b9f77711c3efa0de1abd12456d955d6dd5fe5cc6516dbbfeeec055430dc
# 13834  551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5
# 13811  551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5
# 13641  79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed
# 15669  33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156
#
#                     artist_id time_period     timestamp  position  session_num
# 15264  2pQzh5cuuqpDErGZNaOULd  short       1.700566e+09  40        1
# ...

# %%
#count the number of rows for each user
top_artists_short.groupby('user_id').count()
# Out:
#                                                                   artist_id  \
# user_id
# 05304b1f0426de6f6659ee3705d94276f0879f5f82620135d6e3129cd7dd38f6  7
# 190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49  24
# 193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446  15
# 2aba0b9f77711c3efa0de1abd12456d955d6dd5fe5cc6516dbbfeeec055430dc  37
# 310c2c931b0a40733bceb933951538cff2cbf5efba6c86eb30017d138f8615a2  23
# 33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156  50
# 511b89b7678ce0a6e47fb855449464db2e11ee734c301e02b6ce64d1028f68f3  32
# 551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5  50
# 58f837a105c6522d77e92b579551994b382885c33109e08252aa30cbc46501d8  6
# 612a1db40349f4a4af4bb80973dc6465438019891bd96d3ff5407c47fb621e9b  32
# 79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed  50
# 90bfc065f3b6aa5d8a99acdb968507dafc3827128e4244bba1c192f5d2ef0b73  45
# ...

# %%
#get only the roes where position is between 1 and 5
top_artists_short = top_artists_short[top_artists_short['position']<5]
top_artists_short.sample(10)
# Out:
#                                                                 user_id  \
# 9447   9437dc89b5bb246db5fcf9f45311e7b07a13759e87609efe8b79759e69a3d463
# 13603  79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed
# 9449   9437dc89b5bb246db5fcf9f45311e7b07a13759e87609efe8b79759e69a3d463
# 14162  58f837a105c6522d77e92b579551994b382885c33109e08252aa30cbc46501d8
# 16853  a475d51e39c44aea4cc838dd470cd5ee123cab0d7287d577261341e721b5d873
# 15466  511b89b7678ce0a6e47fb855449464db2e11ee734c301e02b6ce64d1028f68f3
# 9930   d875aee368e99e7978114b7ffc2bb1f18711d3fe13ae3c090daa2ce73ba12faa
# 16157  612a1db40349f4a4af4bb80973dc6465438019891bd96d3ff5407c47fb621e9b
# 15768  05304b1f0426de6f6659ee3705d94276f0879f5f82620135d6e3129cd7dd38f6
# 16850  a475d51e39c44aea4cc838dd470cd5ee123cab0d7287d577261341e721b5d873
#
#                     artist_id time_period     timestamp  position  session_num
# 9447   0nmQIMXWTXfhgOBdNzhGOs  short       1.699911e+09  1         1
# ...

# %%
top_artists_short.groupby('user_id').count()
# Out:
#                                                                   artist_id  \
# user_id
# 05304b1f0426de6f6659ee3705d94276f0879f5f82620135d6e3129cd7dd38f6  5
# 190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49  5
# 193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446  5
# 2aba0b9f77711c3efa0de1abd12456d955d6dd5fe5cc6516dbbfeeec055430dc  5
# 310c2c931b0a40733bceb933951538cff2cbf5efba6c86eb30017d138f8615a2  5
# 33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156  5
# 511b89b7678ce0a6e47fb855449464db2e11ee734c301e02b6ce64d1028f68f3  5
# 551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5  5
# 58f837a105c6522d77e92b579551994b382885c33109e08252aa30cbc46501d8  5
# 612a1db40349f4a4af4bb80973dc6465438019891bd96d3ff5407c47fb621e9b  5
# 79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed  5
# 90bfc065f3b6aa5d8a99acdb968507dafc3827128e4244bba1c192f5d2ef0b73  5
# ...

# %%
#save the data to a csv file
top_artists_short.to_csv('/Users/giovannibalestrieri/Desktop/Decision Support Systems/Group Assignement/participant data v2 Nov 24/user spotify data/users_and_Top5artists.csv', index=False)

# %%
top_artists_tracks = pd.read_csv('/Users/giovannibalestrieri/Desktop/Decision Support Systems/Group Assignement/participant data v2 Nov 24/user spotify data/users_and_Top5artists_tracks.csv')
top_artists_tracks.sample(10)
# Out:
#                                                               user_id  \
# 896  a475d51e39c44aea4cc838dd470cd5ee123cab0d7287d577261341e721b5d873
# 271  551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5
# 286  551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5
# 1    193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 363  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 122  d875aee368e99e7978114b7ffc2bb1f18711d3fe13ae3c090daa2ce73ba12faa
# 238  79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed
# 248  79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed
# 369  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
# 710  310c2c931b0a40733bceb933951538cff2cbf5efba6c86eb30017d138f8615a2
#
#                   artist_id time_period     timestamp  position  session_num  \
# 896  6LtXxYMIiKSy2EGHnz1f5j  short       1.700647e+09  4         1
# ...

# %%
#rename the artist_top_tracks to track_id
top_artists_tracks.rename(columns={'artist_top_tracks':'track_id'}, inplace=True)

# %%
#get only the columns user_id, artist_id, track_id, acousticness	danceability	duration_ms	energy	instrumentalness	key	liveness	loudness	speechiness	tempo	time_signature	valence
user_tracks = user_tracks_top_tracks[['user_id','track_id','acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','speechiness','tempo','time_signature','valence']]
user_tracks.sample(10)
# Out:
#                                                               user_id  \
# 10   193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 15   193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 432  a1fca725e356f6a875477765434bf7293ee42d8fb723ea287980609e67280287
# 103  d875aee368e99e7978114b7ffc2bb1f18711d3fe13ae3c090daa2ce73ba12faa
# 857  a5d39098c87e169587e9d014ecd0215a35859ac164451a6706e23ce3e6d99394
# 892  a475d51e39c44aea4cc838dd470cd5ee123cab0d7287d577261341e721b5d873
# 557  33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156
# 729  310c2c931b0a40733bceb933951538cff2cbf5efba6c86eb30017d138f8615a2
# 593  33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156
# 615  05304b1f0426de6f6659ee3705d94276f0879f5f82620135d6e3129cd7dd38f6
#
#                    track_id  acousticness  danceability  duration_ms  energy  \
# 10   7aI7e0grZG7s6k1j5KSmAb  0.0741        0.699         146206       0.655
# ...

# %%
top_artists_tracks = top_artists_tracks[['user_id','track_id','acousticness','danceability','duration_ms','energy','instrumentalness','key','liveness','loudness','speechiness','tempo','time_signature','valence']]
top_artists_tracks.sample(10)
# Out:
#                                                               user_id  \
# 521  511b89b7678ce0a6e47fb855449464db2e11ee734c301e02b6ce64d1028f68f3
# 18   193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446
# 296  551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5
# 515  511b89b7678ce0a6e47fb855449464db2e11ee734c301e02b6ce64d1028f68f3
# 948  90bfc065f3b6aa5d8a99acdb968507dafc3827128e4244bba1c192f5d2ef0b73
# 157  e125a1762ff5d8136d0215181b950c586493ae05d82872f1ba546545064994e4
# 770  612a1db40349f4a4af4bb80973dc6465438019891bd96d3ff5407c47fb621e9b
# 477  d5fe9ff3491247b295c45050b90ac74d897e6a266f739d30529fad9b377d95a7
# 830  a5d39098c87e169587e9d014ecd0215a35859ac164451a6706e23ce3e6d99394
# 606  05304b1f0426de6f6659ee3705d94276f0879f5f82620135d6e3129cd7dd38f6
#
#                    track_id  acousticness  danceability  duration_ms  energy  \
# 521  0u2P5u6lvoDfwTYjAADbn4  0.9340        0.351         200186.0     0.296
# ...

# %%
#append the two dataframes and save into a new dataframe
user_tracks = user_tracks.append(top_artists_tracks)
len(user_tracks)
# Out:
# /var/folders/mg/667_zj95427b86bx_17bsgl40000gn/T/ipykernel_18026/3803347253.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_tracks = user_tracks.append(top_artists_tracks)
# 1920

# %%
#coun the number of rows for each user
user_tracks.groupby('user_id').count()
# Out:
#                                                                   track_id  \
# user_id
# 05304b1f0426de6f6659ee3705d94276f0879f5f82620135d6e3129cd7dd38f6  100
# 190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49  100
# 193eb5291b0e35491726ec7c75d6e6220427c992910800a1fa4a9cf64a360446  100
# 2aba0b9f77711c3efa0de1abd12456d955d6dd5fe5cc6516dbbfeeec055430dc  100
# 310c2c931b0a40733bceb933951538cff2cbf5efba6c86eb30017d138f8615a2  100
# 33487f29d18475fa7744365760ad9a09740bb5c43878138c3c846e0a4023e156  100
# 511b89b7678ce0a6e47fb855449464db2e11ee734c301e02b6ce64d1028f68f3  105
# 551fcdd6aabfb4f74943abd8ce2f991df039b3d8d170824bd96dffd3bf12a3c5  100
# 58f837a105c6522d77e92b579551994b382885c33109e08252aa30cbc46501d8  100
# 612a1db40349f4a4af4bb80973dc6465438019891bd96d3ff5407c47fb621e9b  100
# 79ffa09d02af50fbbcb5bb530d95face27190bdfbe59477dd72c70239ed4d2ed  100
# 90bfc065f3b6aa5d8a99acdb968507dafc3827128e4244bba1c192f5d2ef0b73  100
# ...

# %%
#round the following columns to 2 decimal places: acousticness	danceability	duration_ms	energy	instrumentalness	key	liveness	loudness	speechiness	tempo	time_signature	valence
user_tracks['acousticness'] = user_tracks['acousticness'].round(2)
user_tracks['danceability'] = user_tracks['danceability'].round(2)
user_tracks['duration_ms'] = user_tracks['duration_ms'].round(2)
user_tracks['energy'] = user_tracks['energy'].round(2)
user_tracks['instrumentalness'] = user_tracks['instrumentalness'].round(2)
user_tracks['key'] = user_tracks['key'].round(2)
user_tracks['liveness'] = user_tracks['liveness'].round(2)
user_tracks['loudness'] = user_tracks['loudness'].round(2)
user_tracks['speechiness'] = user_tracks['speechiness'].round(2)
user_tracks['tempo'] = user_tracks['tempo'].round(2)
user_tracks['time_signature'] = user_tracks['time_signature'].round(2)
user_tracks['valence'] = user_tracks['valence'].round(2)

# %%
user0_tracks_all_tracks = user_tracks[user_tracks['user_id']=='190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49']

# %%
user0_tracks_all_tracks.sample(1)
# Out:
#                                                               user_id  \
# 380  190a01815669c69dfa5b2a3f8e6934f6cc8bf928ce78a5bfe20cb76518188f49
#
#                    track_id  acousticness  danceability  duration_ms  energy  \
# 380  4KW1lqgSr8TKrvBII0Brf8  0.12          0.72          135920.0     0.57
#
#      instrumentalness  key  liveness  loudness  speechiness  tempo  \
# 380  0.0               7.0  0.54     -4.11      0.05         113.0
#
#      time_signature  valence
# 380  4.0             0.44

# %%
#plot the distibution of acousticness	danceability	duration_ms	energy	instrumentalness	key	liveness	loudness	speechiness	tempo	time_signature	valence for user0 with a line following the distribution
fig, ax = plt.subplots(4, 3, figsize=(20, 20))
sns.distplot(user0_tracks_all_tracks['acousticness'], ax=ax[0,0])
sns.distplot(user0_tracks_all_tracks['danceability'], ax=ax[0,1])
sns.distplot(user0_tracks_all_tracks['duration_ms'], ax=ax[0,2])
sns.distplot(user0_tracks_all_tracks['energy'], ax=ax[1,0])
sns.distplot(user0_tracks_all_tracks['instrumentalness'], ax=ax[1,1])
sns.distplot(user0_tracks_all_tracks['key'], ax=ax[1,2])
sns.distplot(user0_tracks_all_tracks['liveness'], ax=ax[2,0])
sns.distplot(user0_tracks_all_tracks['loudness'], ax=ax[2,1])
sns.distplot(user0_tracks_all_tracks['speechiness'], ax=ax[2,2])
sns.distplot(user0_tracks_all_tracks['tempo'], ax=ax[3,0])
sns.distplot(user0_tracks_all_tracks['time_signature'], ax=ax[3,1])
sns.distplot(user0_tracks_all_tracks['valence'], ax=ax[3,2])
plt.show()
# Out:
# /var/folders/mg/667_zj95427b86bx_17bsgl40000gn/T/ipykernel_18026/283306192.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(user0_tracks_all_tracks['acousticness'], ax=ax[0,0])
# /var/folders/mg/667_zj95427b86bx_17bsgl40000gn/T/ipykernel_18026/283306192.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#plot user0_tracks_top_tracks and user0_tracks_all_tracks on the same graph
fig, ax = plt.subplots(4, 3, figsize=(20, 20))
sns.distplot(user0_tracks_top_tracks['acousticness'], ax=ax[0,0])
sns.distplot(user0_tracks_all_tracks['acousticness'], ax=ax[0,0])
sns.distplot(user0_tracks_top_tracks['danceability'], ax=ax[0,1])
sns.distplot(user0_tracks_all_tracks['danceability'], ax=ax[0,1])
sns.distplot(user0_tracks_top_tracks['duration_ms'], ax=ax[0,2])
sns.distplot(user0_tracks_all_tracks['duration_ms'], ax=ax[0,2])
sns.distplot(user0_tracks_top_tracks['energy'], ax=ax[1,0])
sns.distplot(user0_tracks_all_tracks['energy'], ax=ax[1,0])
sns.distplot(user0_tracks_top_tracks['instrumentalness'], ax=ax[1,1])
sns.distplot(user0_tracks_all_tracks['instrumentalness'], ax=ax[1,1])
sns.distplot(user0_tracks_top_tracks['key'], ax=ax[1,2])
sns.distplot(user0_tracks_all_tracks['key'], ax=ax[1,2])
sns.distplot(user0_tracks_top_tracks['liveness'], ax=ax[2,0])
sns.distplot(user0_tracks_all_tracks['liveness'], ax=ax[2,0])
sns.distplot(user0_tracks_top_tracks['loudness'], ax=ax[2,1])
sns.distplot(user0_tracks_all_tracks['loudness'], ax=ax[2,1])
sns.distplot(user0_tracks_top_tracks['speechiness'], ax=ax[2,2])
sns.distplot(user0_tracks_all_tracks['speechiness'], ax=ax[2,2])
sns.distplot(user0_tracks_top_tracks['tempo'], ax=ax[3,0])
sns.distplot(user0_tracks_all_tracks['tempo'], ax=ax[3,0])
sns.distplot(user0_tracks_top_tracks['time_signature'], ax=ax[3,1])
sns.distplot(user0_tracks_all_tracks['time_signature'], ax=ax[3,1])
sns.distplot(user0_tracks_top_tracks['valence'], ax=ax[3,2])
sns.distplot(user0_tracks_all_tracks['valence'], ax=ax[3,2])
plt.show()
# Out:
# /var/folders/mg/667_zj95427b86bx_17bsgl40000gn/T/ipykernel_18026/491258199.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(user0_tracks_top_tracks['acousticness'], ax=ax[0,0])
# /var/folders/mg/667_zj95427b86bx_17bsgl40000gn/T/ipykernel_18026/491258199.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
import numpy as np

def get_feature_range_quartiles(feature_values):
    
    lower_bound = np.percentile(feature_values, 25)
    upper_bound = np.percentile(feature_values, 75)

    # Calculate the interquartile range (ibr)
    ibr = upper_bound - lower_bound

    # Define the range excluding the first and last 25%
    min_value = lower_bound - 0.5 * ibr  # Adjust as needed
    max_value = upper_bound + 0.5 * ibr  # Adjust as needed

    # Clip the values to ensure they are within the range of the data
    min_value = max(min_value, np.min(feature_values))
    max_value = min(max_value, np.max(feature_values))

    return round(min_value,2), round(max_value,2)

feature = 'liveness'
min_key, max_key  = get_feature_range_quartiles(user0_tracks_all_tracks[feature])
print(min_key, max_key)

print(user0_tracks_all_tracks[(user0_tracks_all_tracks[feature]>=min_key) & (user0_tracks_all_tracks[feature]<=max_key)].count()/len(user0_tracks_all_tracks))
# Out:
# 0.0 0.05
# user_id             0.76
# track_id            0.76
# acousticness        0.76
# danceability        0.76
# duration_ms         0.76
# energy              0.76
# instrumentalness    0.76
# key                 0.76
# liveness            0.76
# loudness            0.76
# speechiness         0.76
# tempo               0.76
# time_signature      0.76
# valence             0.76
# dtype: float64

# %%
import numpy as np
from scipy.stats import mode

def get_mode_interval(data, epsilon_percent):
    # Calculate mode
    mode_result = mode(data)
    mode_value = mode_result.mode[0]

    # Calculate epsilon value
    data_range = np.max(data) - np.min(data)
    epsilon = epsilon_percent * data_range

    # Define the interval
    lower_bound = mode_value - epsilon
    upper_bound = mode_value + epsilon

    return lower_bound, upper_bound, mode_value

# Example usage
your_data = user0_tracks_all_tracks['liveness']
epsilon_percent = 0.15  # You can adjust this percentage
lower, upper, mode_value = get_mode_interval(your_data, epsilon_percent)

print("Mode:", mode_value)
print(f"Interval around the mode: ({lower}, {upper})")
# Out:
# Mode: 0.11
# Interval around the mode: (0.018500000000000003, 0.2015)

# %%
# Example usage
your_data = user0_tracks_all_tracks['energy']
epsilon_percent = 0.15  # You can adjust this percentage
lower, upper, mode_value = get_mode_interval(your_data, epsilon_percent)

print("Mode:", mode_value)
print(f"Interval around the mode: ({lower}, {upper})")
# Out:
# Mode: 0.65
# Interval around the mode: (0.56, 0.74)

# %%
import numpy as np
from scipy.stats import mode

def get_mode_range(data, percentage):
    # Calculate mode
    mode_result = mode(data)
    mode_value = mode_result.mode[0]

    # Calculate the lower and upper bounds around the mode
    lower_bound = mode_value - (percentage / 200) * np.ptp(data)
    upper_bound = mode_value + (percentage / 200) * np.ptp(data)

    return round(lower_bound, 2), round(upper_bound, 2)

# Example usage
your_data = user0_tracks_all_tracks['tempo']
percentage = 45
lower, upper = get_mode_range(your_data, percentage)

print("Mode:", mode_value)
print(f"Range around the mode (containing {percentage}% of the data): ({lower}, {upper})")

#print the density in the range for acousticness
print(user0_tracks_all_tracks[(user0_tracks_all_tracks['tempo']>=lower) & (user0_tracks_all_tracks['tempo']<=upper)].count()/len(user0_tracks_all_tracks))
# Out:
# Mode: 0.65
# Range around the mode (containing 45% of the data): (95.66, 154.34)
# user_id             0.72
# track_id            0.72
# acousticness        0.72
# danceability        0.72
# duration_ms         0.72
# energy              0.72
# instrumentalness    0.72
# key                 0.72
# liveness            0.72
# loudness            0.72
# speechiness         0.72
# tempo               0.72
# time_signature      0.72
# valence             0.72
# dtype: float64
